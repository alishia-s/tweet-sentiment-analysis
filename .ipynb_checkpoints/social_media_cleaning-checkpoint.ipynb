# %% [markdown]
# # SPELL CHECKER

# %%
# !pip install spark-nlp==6.3.3 pyspark==3.3.1
# Out:
# ...
#   Using cached spark_nlp-6.3.3-py2.py3-none-any.whl.metadata (19 kB)
# ...
#   Using cached pyspark-3.3.1.tar.gz (281.4 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached py4j-0.10.9.5-py2.py3-none-any.whl.metadata (1.5 kB)
# Using cached spark_nlp-6.3.3-py2.py3-none-any.whl (758 kB)
# Using cached py4j-0.10.9.5-py2.py3-none-any.whl (199 kB)
# ...
#   Created wheel for pyspark: filename=pyspark-3.3.1-py2.py3-none-any.whl size=281845552 sha256=c09f805a5f4b5ffae0d007c2839a3cd61aa23deb4677d3f273e2479666b75b43
#   Stored in directory: /uufs/chpc.utah.edu/common/home/u1332544/.cache/pip/wheels/51/c8/18/298a4ced8ebb3ab8a7d26a7198c0cc7035abb906bde94a4c4b
# Successfully built pyspark
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [pyspark]m2/3 [pyspark]
# ...

# %%
# Import Spark NLP
from sparknlp.base import *
from sparknlp.annotator import *
from sparknlp.pretrained import PretrainedPipeline
import sparknlp

# %%
spark = sparknlp.start()
# Out:
# :: loading settings :: url = jar:file:/uufs/chpc.utah.edu/common/home/u1332544/my-python-venvs/spark-nlp/lib/python3.9/site-packages/pyspark/jars/ivy-2.5.0.jar!/org/apache/ivy/core/settings/ivysettings.xml
# Ivy Default Cache set to: /uufs/chpc.utah.edu/common/home/u1332544/.ivy2/cache
# The jars for the packages stored in: /uufs/chpc.utah.edu/common/home/u1332544/.ivy2/jars
# com.johnsnowlabs.nlp#spark-nlp_2.12 added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-4421502e-86da-4e54-afd3-9d8492b6a20b;1.0
# 	confs: [default]
# 	found com.johnsnowlabs.nlp#spark-nlp_2.12;6.3.3 in central
# 	found com.typesafe#config;1.4.2 in central
# 	found org.rocksdb#rocksdbjni;6.29.5 in central
# 	found com.amazonaws#aws-java-sdk-s3;1.12.500 in central
# 	found com.amazonaws#aws-java-sdk-kms;1.12.500 in central
# 	found com.amazonaws#aws-java-sdk-core;1.12.500 in central
# 	found commons-logging#commons-logging;1.1.3 in central
# ...

# %%
# documentAssembler = DocumentAssembler()\
#     .setInputCol("text")\
#     .setOutputCol("document")

# tokenizer = RecursiveTokenizer()\
#     .setInputCols(["document"])\
#     .setOutputCol("token")\
#     .setPrefixes(["\"", "(", "[", "\n"])\
#     .setSuffixes([".", ",", "?", ")","!", "'s"])

# spellModel = ContextSpellCheckerModel\
#     .pretrained('spellcheck_dl')\
#     .setInputCols("token")\
#     .setOutputCol("checked")\
#     .setErrorThreshold(4.0)\
#     .setTradeoff(6.0)

# finisher = Finisher()\
#     .setInputCols("checked")

# pipeline = Pipeline(stages = [
#      documentAssembler,
#      tokenizer,
#      spellModel,
#      finisher
#   ])
from sparknlp.pretrained import PretrainedPipeline
pipeline = PretrainedPipeline('check_spelling', lang = 'en')
# annotations =  pipeline.fullAnnotate(""Hello from John Snow Labs ! "")[0]
# annotations.keys()
# Out:
# check_spelling download started this may take some time.
# Approx size to download 884.9 KB
# [ | ]26/03/24 21:03:38 WARN S3AbortableInputStream: Not all bytes were read from the S3ObjectInputStream, aborting HTTP connection. This is likely an error and may result in sub-optimal behavior. Request only the bytes you need via a ranged GET or drain the input stream after use.
# 26/03/24 21:03:38 WARN S3AbortableInputStream: Not all bytes were read from the S3ObjectInputStream, aborting HTTP connection. This is likely an error and may result in sub-optimal behavior. Request only the bytes you need via a ranged GET or drain the input stream after use.
# check_spelling download started this may take some time.
# Approximate size to download 884.9 KB
# Download done! Loading the resource.
# [OK!]

# %%
df = spark.createDataFrame([["Hi, howe ar youu todai?"]]).toDF("text")
annotations = pipeline.transform(df)
print(annotations)
# Out:
# DataFrame[text: string, document: array<struct<annotatorType:string,begin:int,end:int,result:string,metadata:map<string,string>,embeddings:array<float>>>, sentence: array<struct<annotatorType:string,begin:int,end:int,result:string,metadata:map<string,string>,embeddings:array<float>>>, token: array<struct<annotatorType:string,begin:int,end:int,result:string,metadata:map<string,string>,embeddings:array<float>>>, checked: array<struct<annotatorType:string,begin:int,end:int,result:string,metadata:map<string,string>,embeddings:array<float>>>]

# %%
pipeline.annotate("thiss is speled badly")
# Out:
# {'document': ['thiss is speled badly'],
#  'sentence': ['thiss is speled badly'],
#  'token': ['thiss', 'is', 'speled', 'badly'],
#  'checked': ['this', 'is', 'spelled', 'badly']}

# %% [markdown]
# # HASHTAG SPLITTING
